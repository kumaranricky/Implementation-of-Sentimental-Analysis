# %%
import pandas as pd
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
# Read the Excel file
df = pd.read_excel('twitter.xlsx')

# Create a VADERSentiment object
analyzer = SentimentIntensityAnalyzer()

# Calculate the sentiment scores for each text
sentiment_scores = []
for text in df['Text']:
    sentiment_scores.append(analyzer.polarity_scores(text))

# Create a list of the texts
texts = list(df['Text'])

# Display the sentiment scores for each text
for text, sentiment_score in zip(texts, sentiment_scores):
    print("\n\nText:", text)
    print("Positive:", sentiment_score['pos'])
    print("Negative:", sentiment_score['neg'])
    print("Neutral:", sentiment_score['neu'])
    print("Compound:", sentiment_score['compound'])
# Out:
# /usr/local/lib/python3.10/dist-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# Text: Sources : ED had day before yesterday conducted searches in the office and home of GKM Tamilkumaran, Chief of LYCA productions.
#
# Highly placed sources say Kumaran had given confession to ED sleuths that there were huge cash transactions with RedGiant movies in the release of… https://t.co/LGzTL26xNf
# Positive: 0.049
# Negative: 0.0
# Neutral: 0.951
# Compound: 0.3182
#
#
# Text: RT @Itsthatsadguy: For all the hatred that he's receiving despite him being such a gem of a person irl, I seriously wish Thalaivar to be so…
# Positive: 0.085
# Negative: 0.187
# Neutral: 0.728
# Compound: -0.4939
#
#
# Text: RT @Itsthatsadguy: For all the hatred that he's receiving despite him being such a gem of a person irl, I seriously wish Thalaivar to be so…
# Positive: 0.085
# Negative: 0.187
# Neutral: 0.728
# Compound: -0.4939
#
#
# Text: RT @Itsthatsadguy: For all the hatred that he's receiving despite him being such a gem of a person irl, I seriously wish Thalaivar to be so…
# Positive: 0.085
# Negative: 0.187
# Neutral: 0.728
# Compound: -0.4939
#
#
# Text: @sumanthraman Any other Tamil city have his ancestral connection?
# Why you want everything in a big city only?
# Do you think Those who are living in small towns don't have rights for any development ?
# Positive: 0.051
# Negative: 0.0
# Neutral: 0.949
# Compound: 0.212
#
#
# Text: RT @Veer2nd: Remembering HRH Maharaj Kumaran Setupathi of Ramnad Kingdom, the Custodian of holy rameshwaram temple and the titular head of…
# Positive: 0.0
# Negative: 0.0
# Neutral: 1.0
# Compound: 0.0
#
#
# Text: RT @dshukla72: Congratulations Kumaran Thillainadarajah @Kunky founder of SmartSkin Technologies @SmartSkinTech on winning the Entrepreneur…
# Positive: 0.36
# Negative: 0.0
# Neutral: 0.64
# Compound: 0.8074
#
#
# Text: RT @wiseconnector: THIS https://t.co/mV11ka2PA7
# Positive: 0.0
# Negative: 0.0
# Neutral: 1.0
# Compound: 0.0
#
#
# Text: RT @thievyaaa08: Having exam tomorrow  but nothing is getting into my brain...nambikai tha vazhkai poleh????
# Positive: 0.0
# Negative: 0.0
# Neutral: 1.0
# Compound: 0.0
#
#
# Text: Are you looking for a brighter, whiter smile? Look no further than Kumaran Dental Clinic Chennai!
#
#  #teethwhitening #smile #teeth #dentist #dentistry #dental #whiteteeth #cosmeticdentistry #smilemakeover #veneers #dentalcare #oralhealth #beauty #dentalimplants #dentalhygiene https://t.co/Sd7wQjEE3K
# Positive: 0.286
# Negative: 0.054
# Neutral: 0.66
# Compound: 0.8588
#
#
# Text: RT @trthompson68: Great opportunity for ⁦#friscoisd #cen10titans #incubatorchs students.  Served on panel #smugsv23 thank you #unchartedlrn…
# Positive: 0.42
# Negative: 0.0
# Neutral: 0.58
# Compound: 0.8555
#
#
# Text: RT @geleskem: Confidence & poise born from a challenging, yet supportive learning environment.  Thank you for sharing. Great work @friscois…
# Positive: 0.541
# Negative: 0.0
# Neutral: 0.459
# Compound: 0.9382
#
#
# Text: Proving to ravi?
# Or
# Ravi proving to u?
#
# If permanent character for shibu then kumaran.
# Else dont enter my house.
#
# Kk.
# Positive: 0.0
# Negative: 0.0
# Neutral: 1.0
# Compound: 0.0
#
#
# Text: RT @ChennaiIPL: Eyes with a dream! ??
#
# #WhistlePodu #Yellove ?? @msdhoni https://t.co/xthGVQKHrs
# Positive: 0.228
# Negative: 0.0
# Neutral: 0.772
# Compound: 0.5027
#
#
# Text: If shibu harry's legal?
# Not for alex.
# If shibu Ravi's legal?
# Not for kumaran?
#
# Who is legal father for shibu?
# On giving permanent character for daughter so character for mother?
# Positive: 0.232
# Negative: 0.0
# Neutral: 0.768
# Compound: 0.7059
#
#
# Text: @crictalker2 @45Fan_Prathmesh @ImRo45 Atleast he played a 11 run knock in eliminator unlike group stage chokli never seen trophies in life
# Positive: 0.107
# Negative: 0.0
# Neutral: 0.893
# Compound: 0.34
#
#
# Text: If permanent character for shibu?
# Kumaran!!
#
# Alex & shibu if siblings?
# Positive: 0.0
# Negative: 0.0
# Neutral: 1.0
# Compound: 0.0
#
#
# Text: RT @ESPNcricinfo: The first player to take a five-wicket haul in an IPL playoff match ??
#
# Akash Madhwal, that was SENSATIONAL ??
#
# #LSGvMI | #…
# Positive: 0.0
# Negative: 0.0
# Neutral: 1.0
# Compound: 0.0
#
#
# Text: @3xchair Sir, found your positive reference to Robin Wood surprising.
#
# Do you agree with the sexual politics he espouses, and his negative assessments of Spielberg and like ?
# Positive: 0.286
# Negative: 0.099
# Neutral: 0.615
# Compound: 0.7184
#
#
# Text: coinbase is airdropping $RFD ??
#  ??  https://t.co/EaESgSMcnq
#   @ThickkBlonde @sc_kung16 @_Nandha_kumaran @ultimategod9000 @Tuantv0402 @sasha_grnk @ShankarLabana @virayjain @DimashaMadushi2 @Vladbetter @symplyfame @Michaeldiniz357 @gatex_exchange
# Positive: 0.0
# Negative: 0.0
# Neutral: 1.0
# Compound: 0.0
#
#
# Text: @college_kumaran Thank you.
# Positive: 0.556
# Negative: 0.0
# Neutral: 0.444
# Compound: 0.3612
#
#
# Text: I think I hate Kumaran
# Positive: 0.0
# Negative: 0.481
# Neutral: 0.519
# Compound: -0.5719
#
#
# Text: big news from coinbase ??
#  ??  https://t.co/z6C9GOSOwa
#   @DanielKonate3 @deepakpatil1999 @CarlosGambinos6 @decentralizID @Mgrowthinvest @Adina1975 @Dr_Arul_Kumaran @alanleha @Web3IDN @SatoshiLegends @8dMb9 @Tom_azad @ObinnaSimon17
# Positive: 0.0
# Negative: 0.0
# Neutral: 1.0
# Compound: 0.0
#
#
# Text: For all the hatred that he's receiving despite him being such a gem of a person irl, I seriously wish Thalaivar to be some N.G.Kumaran & make it big for the masses
#
# The Thalaivar we Tamil people deserve??
#
# Political entry when, Thalaivaaa @Suriya_offl annaaaaa?
#
# #Kanguva⚡#Suriya https://t.co/GCooyvkgKI
# Positive: 0.05
# Negative: 0.119
# Neutral: 0.831
# Compound: -0.5775
#
#
# Text: @3Pavitri U looking so cute bby
# Positive: 0.436
# Negative: 0.0
# Neutral: 0.564
# Compound: 0.5949
#
#
# Text: RT @HelpingChads: Father of the year award ?? https://t.co/yNppw3bOMc
# Positive: 0.325
# Negative: 0.0
# Neutral: 0.675
# Compound: 0.594
#
#
# Text: don't forget to claim coinbase airdrop
#  ??  https://t.co/BiW1PUKcJH
#   @1Paracausal @SurajManithaku1 @k_k__tiwari @pavanp8296 @Mr_Shubham2742 @HackerTech15 @01Siddh @pizzaopop0507 @KalyanSenapti @Suryapaul99 @Kumaran_ravi19 @yolaldiran @amitkahar454
# Positive: 0.092
# Negative: 0.0
# Neutral: 0.908
# Compound: 0.2561
#
#
# Text: RT @Leo_Tweets: #Leo's are often disappointed because their expectations of people are too high.
# Positive: 0.0
# Negative: 0.193
# Neutral: 0.807
# Compound: -0.4767
#
#
# Text: RT @ChennaiIPL: Our gr8est showman! ????
#
# #WhistlePodu #Yellove #IPL2023 ???? https://t.co/AC6NsBlGwG
# Positive: 0.0
# Negative: 0.0
# Neutral: 1.0
# Compound: 0.0
#
#
# Text: RT @incredibala: Amazing how most people from cine field, when they recount in interviews their experience with #SuperstarRajinikanth, they…
# Positive: 0.174
# Negative: 0.0
# Neutral: 0.826
# Compound: 0.5859
#
#
# Text: RT @I_Raj13: Madness peaks.... Rajinikanth and Dhoni saga continues like hell for @ChennaiIPL ????????
# Two biggest Brands??
# https://t.co/CfNiKnk…
# Positive: 0.096
# Negative: 0.326
# Neutral: 0.578
# Compound: -0.7882
#
#
# Text: RT @IPL: He went viral when he gave "Thala" a grand welcome through his DJ console ??
#
# We got behind the scenes to find out more about DJ Ze…
# Positive: 0.191
# Negative: 0.0
# Neutral: 0.809
# Compound: 0.7476
#
#
# Text: @ndtv yes, essential for poor is marked in Red.
# No it is a burden in green.
# It shows your sick mind
# Positive: 0.089
# Negative: 0.381
# Neutral: 0.53
# Compound: -0.8316
#
#
# Text: RT @AshMark25: You don't need the name / title . Remember the look.
#
# #Thalaivar is coming for his throne :)
#
# #Rajinikanth?? is coming for…
# Positive: 0.127
# Negative: 0.0
# Neutral: 0.873
# Compound: 0.5204
#
#
# Text: RT @tweetngrose: #Jayaram sir about his 1st meeting with Superstar #Rajinikanth.The way he imitates Thalaivar for a few secs is a bliss ??❤️…
# Positive: 0.145
# Negative: 0.0
# Neutral: 0.855
# Compound: 0.6199
#
#
# Text: RT @GopinadhMN: I was at the Book Launch Event and Felt Surprised after Listening to his Thoughts on Hindutva.
#
# Today I am Again Surprised…
# Positive: 0.076
# Negative: 0.0
# Neutral: 0.924
# Compound: 0.2263
#
#
# Text: RT @GopinadhMN: Annamalai Anna Said 6 Months Ago in @arvindneela Book Launch Event in Delhi
#
# That he will Request Modi ji to Receive the Se…
# Positive: 0.0
# Negative: 0.0
# Neutral: 1.0
# Compound: 0.0
#
#
# Text: RT @ikkmurugan: Incidentally, 6 months back, Thalaivar @annamalai_k spoke about the significance of Sengol during the transfer of power dur…
# Positive: 0.1
# Negative: 0.0
# Neutral: 0.9
# Compound: 0.2732
#
#
# Text: RT @Annamalai_4_TN: True love and affection towards our Anna ??✨
# #Annamalai https://t.co/w5LJtwwuSe
# Positive: 0.592
# Negative: 0.0
# Neutral: 0.408
# Compound: 0.9195
#
#
# Text: RT @annamalai_k: Today our Hon Home Minister Thiru @AmitShah avl elaborated in a press meeting on the importance of a Chola dynasty Sengol…
# Positive: 0.102
# Negative: 0.0
# Neutral: 0.898
# Compound: 0.3612
#
#
# Text: RT @DeerajVaidy: Mahi Bhai's CSK is the first team in history to defeat the iron clad GT team by taking all their wickets.
# @gujarat_titans…
# Positive: 0.102
# Negative: 0.108
# Neutral: 0.79
# Compound: -0.0431
#
#
# Text: RT @Veer2nd: Remembering HRH Maharaj Kumaran Setupathi of Ramnad Kingdom, the Custodian of holy rameshwaram temple and the titular head of…
# Positive: 0.0
# Negative: 0.0
# Neutral: 1.0
# Compound: 0.0
#
#
# Text: @ChennaiTraffic
#
# Defective Number. Can't able to find which state vehicle itself.
#
# Location: T.Nagar Junction ( Kumaran Silks Opposite)
#
# Date : 23.05.2023
#
# Time : 4:58PM https://t.co/LcK9JAul2F
# Positive: 0.048
# Negative: 0.107
# Neutral: 0.846
# Compound: -0.3818
#
#
# Text: Remembering HRH Maharaj Kumaran Setupathi of Ramnad Kingdom, the Custodian of holy rameshwaram temple and the titular head of the Madurai Tamil Sangam on his 1st year death anniversary. Many temples were renovated in his reign. A blood donation camp was organised in his memory. https://t.co/mfiWNpQBrP
# Positive: 0.0
# Negative: 0.08
# Neutral: 0.92
# Compound: -0.5994
#
#
# Text: RT @Bitgertventures: ?? We're thrilled to announce that we've made an strategic investment of $2.1M USD in @MuratiAI
#
# Read more: https://t.…
# Positive: 0.14
# Negative: 0.0
# Neutral: 0.86
# Compound: 0.504
#
#
# Text: Discover this recently published special issue from Results in Engineering: Catalysis for sustainable energy and fuel production. Edited by Honey John, Anandhan Srinivasan, Sreejalekshmi Kumaran Girija, Soney Varghese. Read open access https://t.co/05TiMYYQ67 @ResultsinEngin1 https://t.co/kJFJEpr0M4
# Positive: 0.13
# Negative: 0.0
# Neutral: 0.87
# Compound: 0.5859
#
#
# Text: RT @rajasthanroyals: May you continue with a backdrop of Pink, @dhruvjurel21. ?? https://t.co/TRsA1M9Dvd
# Positive: 0.0
# Negative: 0.0
# Neutral: 1.0
# Compound: 0.0
#
#
# Text: RT @ChennaiIPL: Good luck, Titans! Thank you for a good game of cricket and the camaraderie!
#
# #GTvCSK #WhistlePodu #Yellove ?? https://t.co/…
# Positive: 0.419
# Negative: 0.0
# Neutral: 0.581
# Compound: 0.9051
#
#
# Text: RT @dshukla72: Congratulations Kumaran Thillainadarajah @Kunky founder of SmartSkin Technologies @SmartSkinTech on winning the Entrepreneur…
# Positive: 0.36
# Negative: 0.0
# Neutral: 0.64
# Compound: 0.8074
#
#
# Text: @tkdylan May God sustain you through these tough times sir. You have my prayers and love
# Positive: 0.303
# Negative: 0.072
# Neutral: 0.625
# Compound: 0.7003
#
#
# Text: RT @rajasthanroyals: 17.2 Senapati misfields, Dhoni calms him down, asks him to take a deep breath ??‍??
#
# 17.4 Senapati with a run-out! ??
#
# Ju…
# Positive: 0.134
# Negative: 0.0
# Neutral: 0.866
# Compound: 0.5502
#
#
# Text: RT @ChennaiIPL: The Rocket Ninja slashing through! ⚡️??
#
# #WhistlePodu #Yellove #IPL2023 ???? https://t.co/agtanBg66b
# Positive: 0.0
# Negative: 0.205
# Neutral: 0.795
# Compound: -0.5191
#
#
# Text: RT @ChennaiIPL: DJ elevating the party! ????
#
# #WhistlePodu #Yellove ???? https://t.co/N3iKpOu9Xf
# Positive: 0.283
# Negative: 0.0
# Neutral: 0.717
# Compound: 0.6062
#
#
# Text: @Sillyfellow22 Avatar Watched in 3D in the year 2009 at senthil kumaran theatre in coimbatore my hometown...
# Positive: 0.0
# Negative: 0.0
# Neutral: 1.0
# Compound: 0.0
#
#
# Text: RT @mvapich: Dr. Kalyan Kumaran @argonne_lcf @argonne will deliver the keynote talk at #ExaComm workshop on the Aurora Exascale Architectur…
# Positive: 0.0
# Negative: 0.0
# Neutral: 1.0
# Compound: 0.0
#
#
# Text: RT @MD_ANAS17: @Offline_Mafia Apro enna ride than ?????? https://t.co/c1wT9lPXya
# Positive: 0.0
# Negative: 0.0
# Neutral: 1.0
# Compound: 0.0
#
#
# Text: • M.Kumaran S/O
# • Aarambam
# • viduthalai
#
# What’s yours..❓
#
# #AjithKumar || #VidaaMuyarchi || #EffortsNeverFail ??⚡️ https://t.co/vp44MvZxnG https://t.co/4lw1Sgx07p
# Positive: 0.0
# Negative: 0.0
# Neutral: 1.0
# Compound: 0.0
#
#
# Text: RT @Deepak_Chahar91: Congratulations to the team. I would love to thank Mahi bhai for giving me confidence. I was doubtful whether I could…
# Positive: 0.457
# Negative: 0.067
# Neutral: 0.476
# Compound: 0.9313
#
#
# Text: RT @ChennaiIPL: Steps into the arrow zone! ??
#
# #IPL2023 #WhistlePodu #Yellove ???? https://t.co/dSV05l7hKi
# Positive: 0.0
# Negative: 0.0
# Neutral: 1.0
# Compound: 0.0
#
#
# Text: RT @D_Conway88: Onto the finals we go????Thank you @chennaiipl fans for all your support so far! One last push! #whistlepodu #yellove https:/…
# Positive: 0.168
# Negative: 0.0
# Neutral: 0.832
# Compound: 0.6421
#
#
# Text: RT @ChennaiIPL: Jaddu’s touch of magic! ??✨
#
# #IPL2023 #WhistlePodu #Yellove ????  @imjadeja @msdhoni https://t.co/ASoS7jNniF
# Positive: 0.202
# Negative: 0.0
# Neutral: 0.798
# Compound: 0.5502
#
#
# Text: @JohnDemetry 80s – Wings of Desire
#
# 90s – Schindler's List
#
# 00s – A.I. Artificial Intelligence
#
# 10s – Brawl In Cell Block 99
#
# My Neighbour Totoro, Magnolia, The Tree of Life, and Dunkirk also come to mind
# Positive: 0.139
# Negative: 0.07
# Neutral: 0.791
# Compound: 0.4404
#
#
# Text: RT @dshukla72: Congratulations Kumaran Thillainadarajah @Kunky founder of SmartSkin Technologies @SmartSkinTech on winning the Entrepreneur…
# Positive: 0.36
# Negative: 0.0
# Neutral: 0.64
# Compound: 0.8074
#
#
# Text: @chemexcil in association with Lakshmi kumaran & Sridharan (L&S) organized a webinar on “ANALYSIS AND IMPLICATION ON SUPREME COURTS DECISION ON PRE-IMPORT CONDITION UNDER ADVANCE AUTHORIZATION SCHEME” on 24th May,2023 at 1500 hrs. Around 125 participants attended this webinar. https://t.co/rS41lGyKVu
# Positive: 0.1
# Negative: 0.0
# Neutral: 0.9
# Compound: 0.6523
#
#
# Text: RT @DvSuruli: Learn to live in any situation...
#
# ~Simple life... https://t.co/cOFsZAyH9z
# Positive: 0.0
# Negative: 0.0
# Neutral: 1.0
# Compound: 0.0
#
#
# Text: RT @CricCrazyJohns: Player of the Match award in Qualifier 1 in IPL 2021.
# Player of the Match award in Qualifier 1 in IPL 2023.
#
# The big ma…
# Positive: 0.219
# Negative: 0.0
# Neutral: 0.781
# Compound: 0.7906
#
#
# Text: RT @Rivaba4BJP: 'Work hard in silence, let your success be your noise'.
# More power to you, my love @imjadeja.
# ❤️❤️❤️ https://t.co/JEBWc3hMfb
# Positive: 0.245
# Negative: 0.043
# Neutral: 0.712
# Compound: 0.8176
#
#
# Text: RT @SanthosH_S13: They get benched for the whole season yet they are celebrating for their team’s win. This is CSK atmosphere https://t.co/…
# Positive: 0.273
# Negative: 0.0
# Neutral: 0.727
# Compound: 0.8176
#
#
# Text: RT @JayShah: We are proud to partner @TataCompanies in planting 500 saplings for each dot ball in the @IPL playoffs. Qualifier 1 #GTvsCSK g…
# Positive: 0.119
# Negative: 0.0
# Neutral: 0.881
# Compound: 0.4767
#
#
# Text: RT @IPL: He went viral when he gave "Thala" a grand welcome through his DJ console ??
#
# We got behind the scenes to find out more about DJ Ze…
# Positive: 0.191
# Negative: 0.0
# Neutral: 0.809
# Compound: 0.7476
#
#
# Text: RT @ChennaiIPL: Jaddu on the fore, acing it all! ⚔️??
# 2️⃣2️⃣(1️⃣6️⃣) & 2️⃣/1️⃣8️⃣
#
# #IPL2023 #WhistlePodu #Yellove ???? @imjadeja https://t.co/…
# Positive: 0.0
# Negative: 0.0
# Neutral: 1.0
# Compound: 0.0
#
#
# Text: RT @deepak_chahar9: Last night was LIT… Finals, here we come… ????
#
# #yellove #whistlepodu https://t.co/68R7Y19Qa3
# Positive: 0.0
# Negative: 0.0
# Neutral: 1.0
# Compound: 0.0
#
#
# Text: RT @IPL: Emotions in plenty ??
#
# Moments of elation, pure joy and the feeling of making it to the Final of #TATAIPL 2023 ??
#
# Watch it all here…
# Positive: 0.259
# Negative: 0.0
# Neutral: 0.741
# Compound: 0.8299
#
#
# Text: RT @ChennaiIPL: 6️⃣0️⃣ seconds of pure ????
#
# https://t.co/94nLbjvZM9
# Positive: 0.0
# Negative: 0.0
# Neutral: 1.0
# Compound: 0.0
#
#
# Text: RT @NishantSindhu09: Final No. 10??
#
# What an honour to be a part of this special team!
#
# @ChennaiIPL https://t.co/2p3vukZRIb
# Positive: 0.318
# Negative: 0.0
# Neutral: 0.682
# Compound: 0.8165
#
#
# Text: RT @ChennaiIPL: Navigating through fielding dimensions with prowess! ✨
#
# #WhistlePodu #Yellove #IPL2023 https://t.co/gUS97IYdu8
# Positive: 0.178
# Negative: 0.0
# Neutral: 0.822
# Compound: 0.3802
#
#
# Text: RT @ajinkyarahane88: The journey continues! Finals Bound!
#
# #yellove #whistlepodu https://t.co/68yY3Gh4Om
# Positive: 0.0
# Negative: 0.0
# Neutral: 1.0
# Compound: 0.0
#
#
# Text: RT @ChennaiIPL: The smiling swing squad! ??☄️
#
# #WhistlePodu #Yellove #IPL2023 ?? https://t.co/kTxea51SRW
# Positive: 0.262
# Negative: 0.0
# Neutral: 0.738
# Compound: 0.643
#
#
# Text: RT @Bitgertventures: ?? We're thrilled to announce that we've made an strategic investment of $1.4M USD in @Imovofficial
#
# Read more: https:…
# Positive: 0.14
# Negative: 0.0
# Neutral: 0.86
# Compound: 0.504
#
#
# Text: Malligaye malligaye is a LGBTQ song right
# Positive: 0.0
# Negative: 0.0
# Neutral: 1.0
# Compound: 0.0
#
#
# Text: RT @vxytri: twitter me, instagram me, and real life me are 3 different types of people
# Positive: 0.0
# Negative: 0.0
# Neutral: 1.0
# Compound: 0.0
#
#
# Text: Remembering the wonderful memories that these great shows gave to my generation
#
# @umangjain08 @jay_shree6 @freishiab @devanshdoshi @MarkandSoni https://t.co/KBpGd3LCKh
# Positive: 0.328
# Negative: 0.0
# Neutral: 0.672
# Compound: 0.8316
#
#
# Text: Dr. Kalyan Kumaran @argonne_lcf @argonne will deliver the keynote talk at #ExaComm workshop on the Aurora Exascale Architecture @ISChpc
#
# Time: 2:00PM - 6:00PM
#
# Location: Hall Y9 - 2nd Floor
#
# Details: https://t.co/ObTniQDSdi
# Positive: 0.0
# Negative: 0.0
# Neutral: 1.0
# Compound: 0.0
#
#
# Text: I need briyani https://t.co/FecoHmY8lL
# Positive: 0.0
# Negative: 0.0
# Neutral: 1.0
# Compound: 0.0
#
#
# Text: @SmallTownerr @bose_kumaran @MrSinha_ @ANI Zero following because I want my feed to be empty while Jobless Congressi's are burning.
# Girl's photo?? Asshole - Go to my LinkedIn and check. Unlike you, I earn enough to buy your family. Poor people might be struggling to live while you are preparing for IAS the 25th time.
# Positive: 0.022
# Negative: 0.136
# Neutral: 0.842
# Compound: -0.7757
#
#
# Text: RT @ChennaiIPL: These buoyssssssssss ????❤️??
#
# #IPL2023 #WhistlePodu #Yellove ???? https://t.co/XZOlcQNBys
# Positive: 0.0
# Negative: 0.0
# Neutral: 1.0
# Compound: 0.0
#
#
# Text: @kaalibilly @bose_kumaran @MrSinha_ @ANI Behan, you are exposing yourself by showing such ignorance about facts.
# Btw, I will not argue with such fake people who even don't exist.
# Positive: 0.06
# Negative: 0.228
# Neutral: 0.711
# Compound: -0.6872
#
#
# Text: @kaalibilly @bose_kumaran @MrSinha_ @ANI 0 following,
# Using Girl's name,
# Picking girl's photo from internet,
# And here you are boasting yourself that you roast congressi.??
# Kya duniya hai.
# Positive: 0.0
# Negative: 0.0
# Neutral: 1.0
# Compound: 0.0
#
#
# Text: @SmallTownerr @bose_kumaran @MrSinha_ @ANI First answer my question and then call me names. If you don't have an answer go watch Pokemon like Rahul Gandhi. You must be an IAS aspirant ??.
#
# Jobless and horny like your master.
# Positive: 0.13
# Negative: 0.0
# Neutral: 0.87
# Compound: 0.6553
#
#
# Text: @kaalibilly @bose_kumaran @MrSinha_ @ANI Behan ??
# Thankyou for giving me gyan about FIRs.
# Now can you please also tell me when these FIRs were registered and when wrestlers started their protest and how these FIRs are registered?
# Please come out from your gobarbhakti.
# Positive: 0.155
# Negative: 0.041
# Neutral: 0.803
# Compound: 0.6747
#
#
# Text: @SmallTownerr @bose_kumaran @MrSinha_ @ANI Duff er Congressi. There are two FIR's filed already. Wake up. Stop making a fool of yourself on a public platform like your dumb leader. Pokemon works for him. You have to fight for yourself.
# Positive: 0.053
# Negative: 0.232
# Neutral: 0.716
# Compound: -0.8176
#
#
# Text: @kaalibilly @bose_kumaran @MrSinha_ @ANI Ok, why your modi ji didn't order investigation into this matter?
# Why any FIR was not registered against brij bhushan?
# I Just have one advice, please don't reduce yourself to such an extent that you start to unsee clear facts.
# Positive: 0.135
# Negative: 0.0
# Neutral: 0.865
# Compound: 0.6581
#
#
# Text: @bose_kumaran @SmallTownerr @MrSinha_ @ANI Protestors don't want a solution. They want to take over the wrestling federation and get direct entry to the next Olympics. Not going to happen. When Modi is in power MERIT is the only criterion.
# Positive: 0.112
# Negative: 0.074
# Neutral: 0.814
# Compound: 0.3917
#
#
# Text: It’s a team effort, but the major credit for the second innings purely belongs to “The Greatest cricketing Mastermind”
#
# The Man , The Myth, The cricketing Politician, The Legend  MS DHONI ?????? https://t.co/Qp06CCMBYI
# Positive: 0.255
# Negative: 0.0
# Neutral: 0.745
# Compound: 0.9118
#
#
# Text: RT @vxytri: i'm such a "huh" person
# Positive: 0.0
# Negative: 0.0
# Neutral: 1.0
# Compound: 0.0
#
#
# Text: RT @ChennaiIPL: @ImRaina We ?? You Chinna Thala! ??
# Positive: 0.0
# Negative: 0.0
# Neutral: 1.0
# Compound: 0.0
#
#
# Text: RT @ImRaina: CHAMPIONS ARE BACK! ?? @ChennaiIPL roars into the finals with an outstanding performance! ?? What a nail-biting match! Congratul…
# Positive: 0.344
# Negative: 0.0
# Neutral: 0.656
# Compound: 0.8994
#
#
# Text: RT @ChennaiIPL: Young ones with the big impact! ??
#
# #GTvCSK #WhistlePodu ???? https://t.co/CM10fbDIhG
# Positive: 0.0
# Negative: 0.0
# Neutral: 1.0
# Compound: 0.0
#
#
# Text: RT @ChennaiIPL: The hope that got us going! ⚡️
#
# #GTvCSK #WhistlePodu #Yellove ???? @deepak_chahar9 https://t.co/Xbw9fLZbDt
# Positive: 0.217
# Negative: 0.0
# Neutral: 0.783
# Compound: 0.6312
#
#
# Text: RT @JioCinema: A night to remember at #Anbuden ??
#
# The sea of #Yellove witnessed another remarkable performance from #CSK as they inch close…
# Positive: 0.153
# Negative: 0.0
# Neutral: 0.847
# Compound: 0.6072

# %%
# !pip install vaderSentiment
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: vaderSentiment in /usr/local/lib/python3.10/dist-packages (3.3.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from vaderSentiment) (2.27.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->vaderSentiment) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->vaderSentiment) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->vaderSentiment) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->vaderSentiment) (3.4)
